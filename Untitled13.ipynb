# %% [markdown]
# <a href="https://colab.research.google.com/github/ninonlack/QM2-group-7-/blob/main/Untitled13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd
import pylab
# %matplotlib inline
pylab.rcParams['figure.figsize'] = (30., 15.)

# %%
covidcase_path = "/content/statesvscovidcasesdatasheet.csv"
covidcase = pd.read_csv(covidcase_path)
covidcase.head()
# Out:
#         State  Covid cases in last 7 days
# 0     alabama                        29.0
# 1      alaska                        62.0
# 2     arizona                        23.0
# 3    arkansas                        43.5
# 4  california                        14.9

# %%
covidcase['State'].is_unique
# Out:
# True

# %%
covidcase = pd.read_csv('/content/statesvscovidcasesdatasheet.csv', index_col='State')
print(covidcase)
# Out:
#                       Covid cases in last 7 days
# State
# alabama                                     29.0
# alaska                                      62.0
# arizona                                     23.0
# arkansas                                    43.5
# california                                  14.9
# colorado                                    56.2
# connecticut                                 30.4
# delaware                                    24.9
# district of columbia                        13.2
# florida                                     23.5
# georgia                                     15.3
# hawaii                                       7.5
# idaho                                       68.3
# illinois                                    77.1
# indiana                                     62.6
# iowa                                       116.7
# kansas                                      70.1
# kentucky                                    41.2
# louisiana                                   16.5
# maine                                       12.1
# maryland                                    21.2
# massachusetts                               23.9
# michigan                                    48.6
# minnesota                                   79.4
# mississipi                                  31.7
# missouri                                    56.6
# montana                                     78.0
# nebraska                                    95.8
# nevada                                      41.8
# new hampshire                               14.5
# new jersey                                  25.1
# new mexico                                  55.8
# new york                                    17.0
# north carolina                              23.2
# north dakota                               172.1
# ohio                                        40.4
# oklahoma                                    60.8
# oregon                                      17.7
# pennsylvania                                24.9
# rhode island                                52.6
# south carolina                              21.0
# south dakota                               137.0
# tennessee                                   48.9
# texas                                       26.8
# utah                                        77.6
# vermont                                      4.5
# virginia                                    17.2
# washington                                  17.5
# west virginia                               28.2
# wisconsin                                  101.9
# wyoming                                     95.0

# %%
covidcase.plot()

# %%
covidcase.plot(kind='bar')
